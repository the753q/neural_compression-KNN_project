# %%
from pathlib import Path
import os
import shutil
import subprocess

repo_url = "https://github.com/the753q/neural_compression-KNN_project.git"
repo_dir = Path("/content/neural_compression-KNN_project")

if repo_dir.exists():
    print(f"Removing existing directory: {repo_dir}")
    shutil.rmtree(repo_dir)

subprocess.run(["git", "clone", repo_url, str(repo_dir)], check=True)
os.chdir(repo_dir)
print(f"Current working directory: {Path.cwd()}")

# %%
# !git -C /content/neural_compression-KNN_project status --short
# !ls -la /content/neural_compression-KNN_project
